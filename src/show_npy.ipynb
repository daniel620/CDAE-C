# %%
import numpy as np
import argparse
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
folder_path = '/Volumes/Secrets/Research_DAE/LUNA16-Lung-Nodule-Analysis-2016-Challenge-master/LUNA16Challege/data/classification/'
file_path = ['1/0_0_110.npy','0/0_0_0.npy']
for file in file_path:
    points = np.load(folder_path + file)  # (n, 3)

    fig = plt.figure()
    ax = fig.gca(projection='3d')

    ax.scatter(points[:, 0], points[:, 1], points[:, 2], c='y')
    plt.show()
